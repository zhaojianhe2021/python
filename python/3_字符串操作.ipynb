# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Test='python'
print(type(Test))
# Out:
# <class 'str'>

# %%
#获取第一个字符
print('获取第一个字符:',Test[0:1])
# Out:
# 获取第一个字符: p

# %%
#首字母变大写
name='papter'
name.capitalize()
# Out:
# 'Papter'

# %%
#去除字符串中的空格
a='    hello    '
a.strip()
# Out:
# 'hello'

# %%
a.lstrip()# 删除左边空格
# Out:
# 'hello    '

# %%
a.rstrip()
# Out:
# '    hello'

# %%
b=a#复制，不是赋值
print(b)
# Out:
#     hello

# %%
id(a)# 查看内存地址
# Out:
# 2655989564720

# %%
id(b)# 相同的内存地址
# Out:
# 2655989564720

# %%
dataStr='I love python'
dataStr.find('p') # 查看目标对象在序列中的位置
# Out:
# 7

# %%
dataStr.index('k')# index找不到会报错
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22768/228544587.py in <module>
# ----> 1 dataStr.index('k')# index找不到会报错
#
# ValueError: substring not found

# %%
dataStr.startswith('I')# 以~开头
# Out:
# True

# %%
dataStr.lower()# 全部变成小写
# Out:
# 'i love python'

# %%
dataStr.upper()# 全部变成大写
# Out:
# 'I LOVE PYTHON'

# %%
strMsg='hello world'
strMsg[0]
# slice [start : end : step] 左闭右开
strMsg[2:5] #2-5下标之间的数据
# Out:
# 'llo'

# %%
strMsg[::-1]#-1代表方向，从右往左
# Out:
# 'dlrow olleh'
