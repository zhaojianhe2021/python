# %% [markdown]
# ![image.png](attachment:image.png)

# %%
M=lambda x,y : x+y
#通过变量去调用匿名函数
print(M(23,19))
# Out:
# 42

# %%
result=lambda a,b,c : a*b*c
result(12,34,2)
# Out:
# 816

# %%
func=(lambda x,y : x if x>y else y)(16,12)
func
# Out:
# 16
